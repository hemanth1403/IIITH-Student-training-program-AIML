# %% [markdown]
# # Transforming data using linear algebra
#
# ### Module 1 Lab 4

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.datasets import mnist

# %%
# @title

from IPython.display import Latex as lt
#Plotting functions
#(You DON'T need to understand how these functions)

# function to plot a grid
def plotGrid(transform, unit, linestyle = ':', fig=None, ax=None):
  lim1 = -100
  lim2 = 100
  def mat2xy(start, end):
    if len(start.shape)==1: 
      start = np.expand_dims(start,0)
      end = np.expand_dims(end,0)
    nan = np.ones(len(start))*np.nan
    x = np.stack((start[:,0], end[:,0], nan)).T.reshape(-1)
    y = np.stack((start[:,1], end[:,1], nan)).T.reshape(-1)
    return x, y

  def parallellines(axis, addend, lines, unit):
    addend = np.repeat(np.expand_dims(addend,0), lines*2, 0)
    unit = np.expand_dims(np.arange(-lines, lines)*unit,1)
    unit = unit-lines
    addend = addend*unit
    lines = np.expand_dims(axis,0) + addend
    return np.concatenate((lines, lines*-1))

  if fig is None:
    fig, ax = plt.subplots(figsize=(10,10))
  transform = transform.astype(np.float64)
  xaxis = transform[0]
  yaxis = transform[1]

  # plot lines parallel to the x axis
  lines1= parallellines(xaxis*lim1, yaxis, 100,unit )
  lines2 = parallellines(xaxis*lim2, yaxis, 100,unit )
  x,y = mat2xy(lines1, lines2)
  plt.plot(x,y, linestyle+'k', linewidth=0.5)
  # plot x axis
  x,y = mat2xy(xaxis*lim1, xaxis*lim2)
  plt.plot(x,y,linestyle, color = '#440077')

  # plot  lines parallel to the y axis
  lines1= parallellines(yaxis*lim1, xaxis, 100,unit)
  lines2 = parallellines(yaxis*lim2, xaxis, 100,unit)
  x,y = mat2xy(lines1, lines2)
  plt.plot(x,y, linestyle+'k', linewidth=0.5)
  # plot y axis
  x,y = mat2xy(yaxis*lim1, yaxis*lim2)
  plt.plot(x,y,linestyle, color= '#aa5500')

  return fig, ax

def plotData(X, y, xlabel = 'hole', ylabel = 'bound', fig=None, ax = None):
  if fig is None:
    fig, ax = plt.subplots()
  for ii in range(nclasses):
    plt.scatter(X[y==ii,0], X[y==ii, 1])
  plt.legend([str(i) for i in range(nclasses)])
  plt.xlabel(xlabel)
  plt.ylabel(ylabel)
  lim2 = X.max()
  lim1 = X.min()
  add = abs(lim1-lim2)/5
  return fig, ax

# %% [markdown]
# # Matrix transformations on data
#
# A 2D coordinate system is defined by its basis vectors, i and j. In the standard coordinate system (Let us call it T0), the basis vectors are
#
# $$\begin{equation}
# i = \left\{  \begin{aligned}1 \\ 0 \end{aligned} \right\}
# \end{equation}$$
# and
# $$\begin{equation} j = \left\{ \begin{aligned} 0 \\ 1\end{aligned} \right\} \end{equation}$$
#
# We can use any two vectors as basis vectors for a new coordinate system as long as they are not colinear. For example, let us call this new coordinate system T1:
#
# $$\begin{equation}
# i = \left\{  \begin{aligned}1 \\ -1 \end{aligned} \right\}
# \end{equation}$$
# and
# $$\begin{equation} j = \left\{ \begin{aligned} 0 \\ 2 \end{aligned} \right\} \end{equation}$$
#
# Suppose we have a point [a,b] in the T1 coordinate system. Its representation in the standard system T0 can be obtained by the following matrix multiplication:
#
# $$ \begin{equation}
# \left\{  \begin{aligned}a' \\ b' \end{aligned} \right\} =
# \left\{  \begin{aligned}&1 & 0 \\ -&1 & 2 \end{aligned} \right\}
# \left\{  \begin{aligned}a \\ b \end{aligned} \right\}
# \end{equation}$$
# where the columns of the matrix are the basis vectors of T1.
#
# Let us see this in action:

# %%
T0 = np.array([[1,0],[0,1]])
T1 = np.array([[1,0], [-1,2]])

data1 = np.array([5,4]) # the data in T1 coordinate system
data0 = np.matmul(T1, data1) # the data in T0 coordinate system

print('Data in T0 = ', data0)
print('Data in T1 = ', data1)
# Out:
# Data in T0 =  [5 3]
# Data in T1 =  [5 4]

# %% [markdown]
# We can visualize this below. T0 is shown with dotted lines and T1 is shown with solid lines.

# %%
fig, ax = plotGrid(T1.T, 1,'-') # custom plotting function, no need to understand this
plotGrid(T0.T, 1, fig=fig, ax=ax) # custom plotting function, no need to understand this
plt.scatter(data0[0], data0[1])
ax.set_xlim(-10,10)
ax.set_ylim(-10,10)
ax.set_xticks([]);
ax.set_yticks([]);

# %% [markdown]
# Look at the coordinates of the blue dot. In T0 (dotted lines), the position is [5,3] where it is [5,4] in T1. Feel free to experiment with different data points and coordinate systems.
#
# Remember that we can achieve the same thing by post-multiplying the transpose of the transformation matrix to the data. This will come in handy when transforming multiple data points at once:

# %%
data0_a = np.matmul(T1, data1)
data0_b = np.matmul(data1, T1.T)
print(data0_a)
print(data0_b)
# Out:
# [5 3]
# [5 3]

# %% [markdown]
# Why is transforming data useful? Data transformations cause the distance between data points to change. This will affect distance-based algorithms such as nearest neighbour

# %%
# let us define 3 points in T1
A1 = np.array([3,3])
B1 = np.array([2,-5])
C1 = np.array([1,-1])

# the corresponding points in T0:
A0 = np.matmul(T1, A1)
B0 = np.matmul(T1, B1)
C0 = np.matmul(T1, C1)

# function to calculate Euclidean distance:
def dist(a, b):
  diff = a-b
  sq = diff*diff
  return np.sqrt(sq.sum())

# distance between the points in T1
print('Distance between A and B in T1 = ', dist(A1, B1))
print('Distance between B and C in T1 = ', dist(B1, C1))
print('Distance between A and C in T1 = ', dist(A1, C1))

print('')
# distnace between the points in T0
print('Distance between A and B in T0 = ', dist(A0, B0))
print('Distance between B and C in T0 = ', dist(B0, C0))
print('Distance between A and C in T0 = ', dist(A0, C0))
# Out:
# Distance between A and B in T1 =  8.06225774829855
# Distance between B and C in T1 =  4.123105625617661
# Distance between A and C in T1 =  4.47213595499958
#
# Distance between A and B in T0 =  15.033296378372908
# Distance between B and C in T0 =  9.055385138137417
# Distance between A and C in T0 =  6.324555320336759

# %% [markdown]
# We see that in T1, B and C are the closest whereas in T0, A and C are the closest. These kinds of changes will affect the predictions returned by the nearest neighbour algorithm.

# %% [markdown]
# # Transformations on MNIST
#
# Let us experiment with a subset of the MNIST dataset. We will extract two features from the database for our experiment.

# %% [markdown]
# Functions for nearest neighbour, accuracy and feature extraction. (from previous labs)

# %%
#@title

def NN1(traindata, trainlabel, query):
  diff  = traindata - query  # find the difference between features. Numpy automatically takes care of the size here
  sq = diff*diff # square the differences
  dist = sq.sum(1) # add up the squares
  label = trainlabel[np.argmin(dist)] # our predicted label is the label of the training data which has the least distance from the query
  return label

def NN(traindata, trainlabel, testdata):
  # we will run nearest neighbour for each sample in the test data
  # and collect the predicted classes in an array using list comprehension
  predlabel = np.array([NN1(traindata, trainlabel, i) for i in testdata])
  return predlabel

def Accuracy(gtlabel, predlabel):
  assert len(gtlabel)==len(predlabel), "Length of the groundtruth labels and predicted labels should be the same"
  correct = (gtlabel==predlabel).sum() # count the number of times the groundtruth label is equal to the predicted label.
  return correct/len(gtlabel)

def cumArray(img):
  img2 = img.copy()
  for ii in range(1, img2.shape[1]):
    img2[ii,:] = img2[ii,:] + img2[ii-1,:]  # for every row, add up all the rows above it.
  img2 = img2>0
  return img2

def getHolePixels(img):
  im1 = cumArray(img)
  im2 = np.rot90(cumArray(np.rot90(img)), 3) # rotate and cumulate it again for differnt direction
  im3 = np.rot90(cumArray(np.rot90(img, 2)), 2)
  im4 = np.rot90(cumArray(np.rot90(img, 3)), 1)
  hull =  im1 & im2 & im3 & im4 # this will create a binary image with all the holes filled in.
  hole = hull & ~ (img>0) # remove the original digit to leave behind the holes
  return hole

def getHullPixels(img):
  im1 = cumArray(img)
  im2 = np.rot90(cumArray(np.rot90(img)), 3) # rotate and cumulate it again for differnt direction
  im3 = np.rot90(cumArray(np.rot90(img, 2)), 2)
  im4 = np.rot90(cumArray(np.rot90(img, 3)), 1)
  hull =  im1 & im2 & im3 & im4 # this will create a binary image with all the holes filled in.
  return hull

def minus(a, b):
  return a & ~ b

def getBoundaryPixels(img):
  img = img.copy()>0  # binarize the image
  rshift = np.roll(img, 1, 1)
  lshift = np.roll(img, -1 ,1)
  ushift = np.roll(img, -1, 0)
  dshift = np.roll(img, 1, 0)
  boundary = minus(img, rshift) | minus(img, lshift) | minus(img, ushift) | minus(img, dshift)
  return boundary

# %% [markdown]
# Get the MNIST dataset:

# %%
#loading the dataset
(train_X, train_y), (test_X, test_y) = mnist.load_data()
train_X = train_X/255
test_X = test_X/255

nclasses = 4

# get only for the first 4 classes
train_X = train_X[train_y<nclasses]
train_y = train_y[train_y<nclasses]
test_X = test_X[test_y<nclasses]
test_y = test_y[test_y<nclasses]

train_X = train_X[::100].copy() # We are only taking a subset of the training set
train_y = train_y[::100].copy() # do the same to the labels
test_X = test_X[::100].copy() # taking a subset of the test set. This code takes every 500th sample
test_y = test_y[::100].copy()

# get all the features
train_hole = np.array([getHolePixels(i).sum() for i in train_X])
test_hole = np.array([getHolePixels(i).sum() for i in test_X])
train_bound = np.array([getBoundaryPixels(i).sum() for i in train_X])
test_bound = np.array([getBoundaryPixels(i).sum() for i in test_X])
# train_hull = np.array([getHullPixels(i).sum() for i in train_X])
# test_hull = np.array([getHullPixels(i).sum() for i in test_X])
# train_sum = np.sum(train_X, (1,2))/(28*28)
# test_sum = np.sum(test_X, (1,2))/(28*28)

# create the train and test set by combining the appropriate features
train_feats = np.vstack((train_hole,train_bound)).transpose()
test_feats = np.vstack((test_hole, test_bound)).transpose()

# %% [markdown]
# Let us plot the samples and see what they look like:

# %%
# fix limits of x and y axis so that we can see what is going on
xlim=[-100,300]
ylim=[-100,300]
fig, ax = plotData(train_feats, train_y)
ax.set_xlim(xlim)
ax.set_ylim(ylim)
# Out:
# (-100.0, 300.0)

# %% [markdown]
# Check the baseline accuracy on the test set:

# %%
test_pred = NN(train_feats, train_y, test_feats)
acc = Accuracy(test_y, test_pred)
print('Baseline accuracy = ', acc)
# Out:
# Baseline accuracy =  0.7619047619047619

# %% [markdown]
# Let us try transforming the features and checking their accuracy:

# %%
transform = np.array([[0.5,-0.5],[0,2.5]])
# print(transform.shape, train_feats.shape)
train_feats_t = np.matmul(train_feats, transform.T)
test_feats_t = np.matmul(test_feats, transform.T)  # whatever transform we are applying to the training set should be applied to the test set also

# %%
print(transform)
# Out:
# [[ 0.5 -0.5]
#  [ 0.   2.5]]

# %%
fig, ax = plotData(train_feats_t, train_y)
ax.set_xlim(xlim)
ax.set_ylim(ylim)
# Out:
# (-100.0, 300.0)

# %%
test_pred = NN(train_feats_t, train_y, test_feats_t)
# print(test_pred.shape)
# print(test_y.shape)
acc = Accuracy(test_y, test_pred)
print('Accuracy after transform = ', acc)
# Out:
# Accuracy after transform =  0.8095238095238095

# %% [markdown]
# ## Questions:
# 1. Experiment with different transformation matrices and check the accuracy
# 2. Will the same transform used for these two features also work for other features?

# %%
# 1. A. Different transformation matrices along with their accuracy
transform1 = np.array([[0.5,0],[0.5,2.5]])
train_feats_t = np.matmul(train_feats, transform1.T)
test_feats_t = np.matmul(test_feats, transform1.T)
test_pred = NN(train_feats_t, train_y, test_feats_t)
print("Accuracy after transformation 1 = ", Accuracy(test_y, test_pred))

transform2 = np.array([[5,6],[1,2]])
train_feats_t = np.matmul(train_feats, transform2.T)
test_feats_t = np.matmul(test_feats, transform2.T)
test_pred = NN(train_feats_t, train_y, test_feats_t)
print("Accuracy after transformation 2 = ", Accuracy(test_y, test_pred))

transform3 = np.array([[1,2], [1,2]])
train_feats_t = np.matmul(train_feats, transform3.T)
test_feats_t = np.matmul(test_feats, transform3.T)
test_pred = NN(train_feats_t, train_y, test_feats_t)
print("Accuracy after transformation 3 = ", Accuracy(test_y, test_pred))

transform4 = np.array([[10,9], [100,2]])
train_feats_t = np.matmul(train_feats, transform4.T)
test_feats_t = np.matmul(test_feats, transform4.T)
test_pred = NN(train_feats_t, train_y, test_feats_t)
print("Accuracy after transformation 4 = ", Accuracy(test_y, test_pred))

print("Trying all the possible combination between 0 to 10")
maxAccuracy = -1
x1, y1, x2, y2 = -1, -1, -1, -1
for i1 in range(11):
    for j1 in range(11):
        for i2 in range(11):
            for j2 in range(11):
                t = np.array([[i1, j1], [i2, j2]])
                train_feats_t = np.matmul(train_feats, t.T)
                test_feats_t = np.matmul(test_feats, t.T)
                test_pred = NN(train_feats_t, train_y, test_feats_t)
                acc = Accuracy(test_y, test_pred)
                print("Accuracy after transformation ",[[i1, j1], [i2, j2]], " is = ", acc)
                if(maxAccuracy < acc):
                    maxAccuracy = acc
                    x1, y1, x2, y2 = i1, j1, i2, j2
print("Max Accuarcy obtained at transformation : ", [[x1, y1], [x2, y2]], " i.e Accuracy : ", maxAccuracy)
# Out:
# Accuracy after transformation 1 =  0.7857142857142857
# Accuracy after transformation 2 =  0.6190476190476191
# Accuracy after transformation 3 =  0.6904761904761905
# Accuracy after transformation 4 =  0.7619047619047619
# Trying all the possible combination between 0 to 10
# Accuracy after transformation  [[0, 0], [0, 0]]  is =  0.23809523809523808
# Accuracy after transformation  [[0, 0], [0, 1]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 0], [0, 2]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 0], [0, 3]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 0], [0, 4]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 0], [0, 5]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 0], [0, 6]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 0], [0, 7]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 0], [0, 8]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 0], [0, 9]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 0], [0, 10]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 0], [1, 0]]  is =  0.6190476190476191
# Accuracy after transformation  [[0, 0], [1, 1]]  is =  0.6428571428571429
# Accuracy after transformation  [[0, 0], [1, 2]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 0], [1, 3]]  is =  0.5476190476190477
# Accuracy after transformation  [[0, 0], [1, 4]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 0], [1, 5]]  is =  0.6428571428571429
# Accuracy after transformation  [[0, 0], [1, 6]]  is =  0.6190476190476191
# Accuracy after transformation  [[0, 0], [1, 7]]  is =  0.6428571428571429
# Accuracy after transformation  [[0, 0], [1, 8]]  is =  0.5476190476190477
# Accuracy after transformation  [[0, 0], [1, 9]]  is =  0.6428571428571429
# Accuracy after transformation  [[0, 0], [1, 10]]  is =  0.6666666666666666
# Accuracy after transformation  [[0, 0], [2, 0]]  is =  0.6190476190476191
# Accuracy after transformation  [[0, 0], [2, 1]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 0], [2, 2]]  is =  0.6428571428571429
# Accuracy after transformation  [[0, 0], [2, 3]]  is =  0.6666666666666666
# Accuracy after transformation  [[0, 0], [2, 4]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 0], [2, 5]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 0], [2, 6]]  is =  0.5476190476190477
# Accuracy after transformation  [[0, 0], [2, 7]]  is =  0.5714285714285714
# Accuracy after transformation  [[0, 0], [2, 8]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 0], [2, 9]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 0], [2, 10]]  is =  0.6428571428571429
# Accuracy after transformation  [[0, 0], [3, 0]]  is =  0.6190476190476191
# Accuracy after transformation  [[0, 0], [3, 1]]  is =  0.6190476190476191
# Accuracy after transformation  [[0, 0], [3, 2]]  is =  0.6428571428571429
# Accuracy after transformation  [[0, 0], [3, 3]]  is =  0.6428571428571429
# Accuracy after transformation  [[0, 0], [3, 4]]  is =  0.5476190476190477
# Accuracy after transformation  [[0, 0], [3, 5]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 0], [3, 6]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 0], [3, 7]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 0], [3, 8]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 0], [3, 9]]  is =  0.5476190476190477
# Accuracy after transformation  [[0, 0], [3, 10]]  is =  0.5714285714285714
# Accuracy after transformation  [[0, 0], [4, 0]]  is =  0.6190476190476191
# Accuracy after transformation  [[0, 0], [4, 1]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 0], [4, 2]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 0], [4, 3]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 0], [4, 4]]  is =  0.6428571428571429
# Accuracy after transformation  [[0, 0], [4, 5]]  is =  0.6190476190476191
# Accuracy after transformation  [[0, 0], [4, 6]]  is =  0.6666666666666666
# Accuracy after transformation  [[0, 0], [4, 7]]  is =  0.6428571428571429
# Accuracy after transformation  [[0, 0], [4, 8]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 0], [4, 9]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 0], [4, 10]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 0], [5, 0]]  is =  0.6190476190476191
# Accuracy after transformation  [[0, 0], [5, 1]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 0], [5, 2]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 0], [5, 3]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 0], [5, 4]]  is =  0.6666666666666666
# Accuracy after transformation  [[0, 0], [5, 5]]  is =  0.6428571428571429
# Accuracy after transformation  [[0, 0], [5, 6]]  is =  0.5714285714285714
# Accuracy after transformation  [[0, 0], [5, 7]]  is =  0.6190476190476191
# Accuracy after transformation  [[0, 0], [5, 8]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 0], [5, 9]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 0], [5, 10]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 0], [6, 0]]  is =  0.6190476190476191
# Accuracy after transformation  [[0, 0], [6, 1]]  is =  0.6428571428571429
# Accuracy after transformation  [[0, 0], [6, 2]]  is =  0.6190476190476191
# Accuracy after transformation  [[0, 0], [6, 3]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 0], [6, 4]]  is =  0.6428571428571429
# Accuracy after transformation  [[0, 0], [6, 5]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 0], [6, 6]]  is =  0.6428571428571429
# Accuracy after transformation  [[0, 0], [6, 7]]  is =  0.6428571428571429
# Accuracy after transformation  [[0, 0], [6, 8]]  is =  0.5476190476190477
# Accuracy after transformation  [[0, 0], [6, 9]]  is =  0.6666666666666666
# Accuracy after transformation  [[0, 0], [6, 10]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 0], [7, 0]]  is =  0.6190476190476191
# Accuracy after transformation  [[0, 0], [7, 1]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 0], [7, 2]]  is =  0.6428571428571429
# Accuracy after transformation  [[0, 0], [7, 3]]  is =  0.6666666666666666
# Accuracy after transformation  [[0, 0], [7, 4]]  is =  0.6666666666666666
# Accuracy after transformation  [[0, 0], [7, 5]]  is =  0.5476190476190477
# Accuracy after transformation  [[0, 0], [7, 6]]  is =  0.6428571428571429
# Accuracy after transformation  [[0, 0], [7, 7]]  is =  0.6428571428571429
# Accuracy after transformation  [[0, 0], [7, 8]]  is =  0.5476190476190477
# Accuracy after transformation  [[0, 0], [7, 9]]  is =  0.5714285714285714
# Accuracy after transformation  [[0, 0], [7, 10]]  is =  0.6190476190476191
# Accuracy after transformation  [[0, 0], [8, 0]]  is =  0.6190476190476191
# Accuracy after transformation  [[0, 0], [8, 1]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 0], [8, 2]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 0], [8, 3]]  is =  0.6190476190476191
# Accuracy after transformation  [[0, 0], [8, 4]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 0], [8, 5]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 0], [8, 6]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 0], [8, 7]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 0], [8, 8]]  is =  0.6428571428571429
# Accuracy after transformation  [[0, 0], [8, 9]]  is =  0.6190476190476191
# Accuracy after transformation  [[0, 0], [8, 10]]  is =  0.6190476190476191
# Accuracy after transformation  [[0, 0], [9, 0]]  is =  0.6190476190476191
# Accuracy after transformation  [[0, 0], [9, 1]]  is =  0.6428571428571429
# Accuracy after transformation  [[0, 0], [9, 2]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 0], [9, 3]]  is =  0.6190476190476191
# Accuracy after transformation  [[0, 0], [9, 4]]  is =  0.6428571428571429
# Accuracy after transformation  [[0, 0], [9, 5]]  is =  0.6428571428571429
# Accuracy after transformation  [[0, 0], [9, 6]]  is =  0.6428571428571429
# Accuracy after transformation  [[0, 0], [9, 7]]  is =  0.6428571428571429
# Accuracy after transformation  [[0, 0], [9, 8]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 0], [9, 9]]  is =  0.6428571428571429
# Accuracy after transformation  [[0, 0], [9, 10]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 0], [10, 0]]  is =  0.6190476190476191
# Accuracy after transformation  [[0, 0], [10, 1]]  is =  0.6428571428571429
# Accuracy after transformation  [[0, 0], [10, 2]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 0], [10, 3]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 0], [10, 4]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 0], [10, 5]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 0], [10, 6]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 0], [10, 7]]  is =  0.6190476190476191
# Accuracy after transformation  [[0, 0], [10, 8]]  is =  0.6666666666666666
# Accuracy after transformation  [[0, 0], [10, 9]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 0], [10, 10]]  is =  0.6428571428571429
# Accuracy after transformation  [[0, 1], [0, 0]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 1], [0, 1]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 1], [0, 2]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 1], [0, 3]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 1], [0, 4]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 1], [0, 5]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 1], [0, 6]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 1], [0, 7]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 1], [0, 8]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 1], [0, 9]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 1], [0, 10]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 1], [1, 0]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 1], [1, 1]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 1], [1, 2]]  is =  0.8095238095238095
# Accuracy after transformation  [[0, 1], [1, 3]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 1], [1, 4]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 1], [1, 5]]  is =  0.7857142857142857
# Accuracy after transformation  [[0, 1], [1, 6]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 1], [1, 7]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 1], [1, 8]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 1], [1, 9]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 1], [1, 10]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 1], [2, 0]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 1], [2, 1]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 1], [2, 2]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 1], [2, 3]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 1], [2, 4]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 1], [2, 5]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 1], [2, 6]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 1], [2, 7]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 1], [2, 8]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 1], [2, 9]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 1], [2, 10]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 1], [3, 0]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 1], [3, 1]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 1], [3, 2]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 1], [3, 3]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 1], [3, 4]]  is =  0.6428571428571429
# Accuracy after transformation  [[0, 1], [3, 5]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 1], [3, 6]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 1], [3, 7]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 1], [3, 8]]  is =  0.7857142857142857
# Accuracy after transformation  [[0, 1], [3, 9]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 1], [3, 10]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 1], [4, 0]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 1], [4, 1]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 1], [4, 2]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 1], [4, 3]]  is =  0.6666666666666666
# Accuracy after transformation  [[0, 1], [4, 4]]  is =  0.6666666666666666
# Accuracy after transformation  [[0, 1], [4, 5]]  is =  0.6428571428571429
# Accuracy after transformation  [[0, 1], [4, 6]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 1], [4, 7]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 1], [4, 8]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 1], [4, 9]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 1], [4, 10]]  is =  0.8095238095238095
# Accuracy after transformation  [[0, 1], [5, 0]]  is =  0.7857142857142857
# Accuracy after transformation  [[0, 1], [5, 1]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 1], [5, 2]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 1], [5, 3]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 1], [5, 4]]  is =  0.6666666666666666
# Accuracy after transformation  [[0, 1], [5, 5]]  is =  0.6428571428571429
# Accuracy after transformation  [[0, 1], [5, 6]]  is =  0.6428571428571429
# Accuracy after transformation  [[0, 1], [5, 7]]  is =  0.6428571428571429
# Accuracy after transformation  [[0, 1], [5, 8]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 1], [5, 9]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 1], [5, 10]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 1], [6, 0]]  is =  0.7857142857142857
# Accuracy after transformation  [[0, 1], [6, 1]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 1], [6, 2]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 1], [6, 3]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 1], [6, 4]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 1], [6, 5]]  is =  0.6190476190476191
# Accuracy after transformation  [[0, 1], [6, 6]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 1], [6, 7]]  is =  0.6428571428571429
# Accuracy after transformation  [[0, 1], [6, 8]]  is =  0.6428571428571429
# Accuracy after transformation  [[0, 1], [6, 9]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 1], [6, 10]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 1], [7, 0]]  is =  0.7857142857142857
# Accuracy after transformation  [[0, 1], [7, 1]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 1], [7, 2]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 1], [7, 3]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 1], [7, 4]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 1], [7, 5]]  is =  0.6666666666666666
# Accuracy after transformation  [[0, 1], [7, 6]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 1], [7, 7]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 1], [7, 8]]  is =  0.6190476190476191
# Accuracy after transformation  [[0, 1], [7, 9]]  is =  0.6666666666666666
# Accuracy after transformation  [[0, 1], [7, 10]]  is =  0.6666666666666666
# Accuracy after transformation  [[0, 1], [8, 0]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 1], [8, 1]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 1], [8, 2]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 1], [8, 3]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 1], [8, 4]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 1], [8, 5]]  is =  0.7857142857142857
# Accuracy after transformation  [[0, 1], [8, 6]]  is =  0.5714285714285714
# Accuracy after transformation  [[0, 1], [8, 7]]  is =  0.6190476190476191
# Accuracy after transformation  [[0, 1], [8, 8]]  is =  0.6190476190476191
# Accuracy after transformation  [[0, 1], [8, 9]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 1], [8, 10]]  is =  0.6428571428571429
# Accuracy after transformation  [[0, 1], [9, 0]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 1], [9, 1]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 1], [9, 2]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 1], [9, 3]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 1], [9, 4]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 1], [9, 5]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 1], [9, 6]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 1], [9, 7]]  is =  0.5714285714285714
# Accuracy after transformation  [[0, 1], [9, 8]]  is =  0.6190476190476191
# Accuracy after transformation  [[0, 1], [9, 9]]  is =  0.6190476190476191
# Accuracy after transformation  [[0, 1], [9, 10]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 1], [10, 0]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 1], [10, 1]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 1], [10, 2]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 1], [10, 3]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 1], [10, 4]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 1], [10, 5]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 1], [10, 6]]  is =  0.7857142857142857
# Accuracy after transformation  [[0, 1], [10, 7]]  is =  0.6666666666666666
# Accuracy after transformation  [[0, 1], [10, 8]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 1], [10, 9]]  is =  0.6428571428571429
# Accuracy after transformation  [[0, 1], [10, 10]]  is =  0.6190476190476191
# Accuracy after transformation  [[0, 2], [0, 0]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 2], [0, 1]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 2], [0, 2]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 2], [0, 3]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 2], [0, 4]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 2], [0, 5]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 2], [0, 6]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 2], [0, 7]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 2], [0, 8]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 2], [0, 9]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 2], [0, 10]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 2], [1, 0]]  is =  0.8095238095238095
# Accuracy after transformation  [[0, 2], [1, 1]]  is =  0.7857142857142857
# Accuracy after transformation  [[0, 2], [1, 2]]  is =  0.8095238095238095
# Accuracy after transformation  [[0, 2], [1, 3]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 2], [1, 4]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 2], [1, 5]]  is =  0.7857142857142857
# Accuracy after transformation  [[0, 2], [1, 6]]  is =  0.7857142857142857
# Accuracy after transformation  [[0, 2], [1, 7]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 2], [1, 8]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 2], [1, 9]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 2], [1, 10]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 2], [2, 0]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 2], [2, 1]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 2], [2, 2]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 2], [2, 3]]  is =  0.7857142857142857
# Accuracy after transformation  [[0, 2], [2, 4]]  is =  0.8095238095238095
# Accuracy after transformation  [[0, 2], [2, 5]]  is =  0.8095238095238095
# Accuracy after transformation  [[0, 2], [2, 6]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 2], [2, 7]]  is =  0.7857142857142857
# Accuracy after transformation  [[0, 2], [2, 8]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 2], [2, 9]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 2], [2, 10]]  is =  0.7857142857142857
# Accuracy after transformation  [[0, 2], [3, 0]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 2], [3, 1]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 2], [3, 2]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 2], [3, 3]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 2], [3, 4]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 2], [3, 5]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 2], [3, 6]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 2], [3, 7]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 2], [3, 8]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 2], [3, 9]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 2], [3, 10]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 2], [4, 0]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 2], [4, 1]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 2], [4, 2]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 2], [4, 3]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 2], [4, 4]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 2], [4, 5]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 2], [4, 6]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 2], [4, 7]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 2], [4, 8]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 2], [4, 9]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 2], [4, 10]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 2], [5, 0]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 2], [5, 1]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 2], [5, 2]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 2], [5, 3]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 2], [5, 4]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 2], [5, 5]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 2], [5, 6]]  is =  0.6190476190476191
# Accuracy after transformation  [[0, 2], [5, 7]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 2], [5, 8]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 2], [5, 9]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 2], [5, 10]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 2], [6, 0]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 2], [6, 1]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 2], [6, 2]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 2], [6, 3]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 2], [6, 4]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 2], [6, 5]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 2], [6, 6]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 2], [6, 7]]  is =  0.6428571428571429
# Accuracy after transformation  [[0, 2], [6, 8]]  is =  0.6428571428571429
# Accuracy after transformation  [[0, 2], [6, 9]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 2], [6, 10]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 2], [7, 0]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 2], [7, 1]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 2], [7, 2]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 2], [7, 3]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 2], [7, 4]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 2], [7, 5]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 2], [7, 6]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 2], [7, 7]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 2], [7, 8]]  is =  0.6428571428571429
# Accuracy after transformation  [[0, 2], [7, 9]]  is =  0.6428571428571429
# Accuracy after transformation  [[0, 2], [7, 10]]  is =  0.6666666666666666
# Accuracy after transformation  [[0, 2], [8, 0]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 2], [8, 1]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 2], [8, 2]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 2], [8, 3]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 2], [8, 4]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 2], [8, 5]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 2], [8, 6]]  is =  0.6666666666666666
# Accuracy after transformation  [[0, 2], [8, 7]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 2], [8, 8]]  is =  0.6666666666666666
# Accuracy after transformation  [[0, 2], [8, 9]]  is =  0.6428571428571429
# Accuracy after transformation  [[0, 2], [8, 10]]  is =  0.6428571428571429
# Accuracy after transformation  [[0, 2], [9, 0]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 2], [9, 1]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 2], [9, 2]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 2], [9, 3]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 2], [9, 4]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 2], [9, 5]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 2], [9, 6]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 2], [9, 7]]  is =  0.6666666666666666
# Accuracy after transformation  [[0, 2], [9, 8]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 2], [9, 9]]  is =  0.6428571428571429
# Accuracy after transformation  [[0, 2], [9, 10]]  is =  0.6428571428571429
# Accuracy after transformation  [[0, 2], [10, 0]]  is =  0.7857142857142857
# Accuracy after transformation  [[0, 2], [10, 1]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 2], [10, 2]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 2], [10, 3]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 2], [10, 4]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 2], [10, 5]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 2], [10, 6]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 2], [10, 7]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 2], [10, 8]]  is =  0.6666666666666666
# Accuracy after transformation  [[0, 2], [10, 9]]  is =  0.6666666666666666
# Accuracy after transformation  [[0, 2], [10, 10]]  is =  0.6428571428571429
# Accuracy after transformation  [[0, 3], [0, 0]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 3], [0, 1]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 3], [0, 2]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 3], [0, 3]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 3], [0, 4]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 3], [0, 5]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 3], [0, 6]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 3], [0, 7]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 3], [0, 8]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 3], [0, 9]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 3], [0, 10]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 3], [1, 0]]  is =  0.8095238095238095
# Accuracy after transformation  [[0, 3], [1, 1]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 3], [1, 2]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 3], [1, 3]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 3], [1, 4]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 3], [1, 5]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 3], [1, 6]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 3], [1, 7]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 3], [1, 8]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 3], [1, 9]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 3], [1, 10]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 3], [2, 0]]  is =  0.7857142857142857
# Accuracy after transformation  [[0, 3], [2, 1]]  is =  0.7857142857142857
# Accuracy after transformation  [[0, 3], [2, 2]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 3], [2, 3]]  is =  0.8333333333333334
# Accuracy after transformation  [[0, 3], [2, 4]]  is =  0.8095238095238095
# Accuracy after transformation  [[0, 3], [2, 5]]  is =  0.8095238095238095
# Accuracy after transformation  [[0, 3], [2, 6]]  is =  0.7857142857142857
# Accuracy after transformation  [[0, 3], [2, 7]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 3], [2, 8]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 3], [2, 9]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 3], [2, 10]]  is =  0.7857142857142857
# Accuracy after transformation  [[0, 3], [3, 0]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 3], [3, 1]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 3], [3, 2]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 3], [3, 3]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 3], [3, 4]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 3], [3, 5]]  is =  0.7857142857142857
# Accuracy after transformation  [[0, 3], [3, 6]]  is =  0.8095238095238095
# Accuracy after transformation  [[0, 3], [3, 7]]  is =  0.8095238095238095
# Accuracy after transformation  [[0, 3], [3, 8]]  is =  0.8095238095238095
# Accuracy after transformation  [[0, 3], [3, 9]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 3], [3, 10]]  is =  0.7857142857142857
# Accuracy after transformation  [[0, 3], [4, 0]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 3], [4, 1]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 3], [4, 2]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 3], [4, 3]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 3], [4, 4]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 3], [4, 5]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 3], [4, 6]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 3], [4, 7]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 3], [4, 8]]  is =  0.7857142857142857
# Accuracy after transformation  [[0, 3], [4, 9]]  is =  0.7857142857142857
# Accuracy after transformation  [[0, 3], [4, 10]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 3], [5, 0]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 3], [5, 1]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 3], [5, 2]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 3], [5, 3]]  is =  0.6666666666666666
# Accuracy after transformation  [[0, 3], [5, 4]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 3], [5, 5]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 3], [5, 6]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 3], [5, 7]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 3], [5, 8]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 3], [5, 9]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 3], [5, 10]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 3], [6, 0]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 3], [6, 1]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 3], [6, 2]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 3], [6, 3]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 3], [6, 4]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 3], [6, 5]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 3], [6, 6]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 3], [6, 7]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 3], [6, 8]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 3], [6, 9]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 3], [6, 10]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 3], [7, 0]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 3], [7, 1]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 3], [7, 2]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 3], [7, 3]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 3], [7, 4]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 3], [7, 5]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 3], [7, 6]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 3], [7, 7]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 3], [7, 8]]  is =  0.6428571428571429
# Accuracy after transformation  [[0, 3], [7, 9]]  is =  0.6666666666666666
# Accuracy after transformation  [[0, 3], [7, 10]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 3], [8, 0]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 3], [8, 1]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 3], [8, 2]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 3], [8, 3]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 3], [8, 4]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 3], [8, 5]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 3], [8, 6]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 3], [8, 7]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 3], [8, 8]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 3], [8, 9]]  is =  0.6428571428571429
# Accuracy after transformation  [[0, 3], [8, 10]]  is =  0.6428571428571429
# Accuracy after transformation  [[0, 3], [9, 0]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 3], [9, 1]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 3], [9, 2]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 3], [9, 3]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 3], [9, 4]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 3], [9, 5]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 3], [9, 6]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 3], [9, 7]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 3], [9, 8]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 3], [9, 9]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 3], [9, 10]]  is =  0.6666666666666666
# Accuracy after transformation  [[0, 3], [10, 0]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 3], [10, 1]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 3], [10, 2]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 3], [10, 3]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 3], [10, 4]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 3], [10, 5]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 3], [10, 6]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 3], [10, 7]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 3], [10, 8]]  is =  0.6666666666666666
# Accuracy after transformation  [[0, 3], [10, 9]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 3], [10, 10]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 4], [0, 0]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 4], [0, 1]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 4], [0, 2]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 4], [0, 3]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 4], [0, 4]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 4], [0, 5]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 4], [0, 6]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 4], [0, 7]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 4], [0, 8]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 4], [0, 9]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 4], [0, 10]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 4], [1, 0]]  is =  0.7857142857142857
# Accuracy after transformation  [[0, 4], [1, 1]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 4], [1, 2]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 4], [1, 3]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 4], [1, 4]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 4], [1, 5]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 4], [1, 6]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 4], [1, 7]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 4], [1, 8]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 4], [1, 9]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 4], [1, 10]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 4], [2, 0]]  is =  0.8095238095238095
# Accuracy after transformation  [[0, 4], [2, 1]]  is =  0.8095238095238095
# Accuracy after transformation  [[0, 4], [2, 2]]  is =  0.7857142857142857
# Accuracy after transformation  [[0, 4], [2, 3]]  is =  0.8095238095238095
# Accuracy after transformation  [[0, 4], [2, 4]]  is =  0.8095238095238095
# Accuracy after transformation  [[0, 4], [2, 5]]  is =  0.7857142857142857
# Accuracy after transformation  [[0, 4], [2, 6]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 4], [2, 7]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 4], [2, 8]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 4], [2, 9]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 4], [2, 10]]  is =  0.7857142857142857
# Accuracy after transformation  [[0, 4], [3, 0]]  is =  0.7857142857142857
# Accuracy after transformation  [[0, 4], [3, 1]]  is =  0.7857142857142857
# Accuracy after transformation  [[0, 4], [3, 2]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 4], [3, 3]]  is =  0.7857142857142857
# Accuracy after transformation  [[0, 4], [3, 4]]  is =  0.7857142857142857
# Accuracy after transformation  [[0, 4], [3, 5]]  is =  0.8333333333333334
# Accuracy after transformation  [[0, 4], [3, 6]]  is =  0.8095238095238095
# Accuracy after transformation  [[0, 4], [3, 7]]  is =  0.8095238095238095
# Accuracy after transformation  [[0, 4], [3, 8]]  is =  0.8095238095238095
# Accuracy after transformation  [[0, 4], [3, 9]]  is =  0.7857142857142857
# Accuracy after transformation  [[0, 4], [3, 10]]  is =  0.7857142857142857
# Accuracy after transformation  [[0, 4], [4, 0]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 4], [4, 1]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 4], [4, 2]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 4], [4, 3]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 4], [4, 4]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 4], [4, 5]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 4], [4, 6]]  is =  0.7857142857142857
# Accuracy after transformation  [[0, 4], [4, 7]]  is =  0.8333333333333334
# Accuracy after transformation  [[0, 4], [4, 8]]  is =  0.8095238095238095
# Accuracy after transformation  [[0, 4], [4, 9]]  is =  0.8095238095238095
# Accuracy after transformation  [[0, 4], [4, 10]]  is =  0.8095238095238095
# Accuracy after transformation  [[0, 4], [5, 0]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 4], [5, 1]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 4], [5, 2]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 4], [5, 3]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 4], [5, 4]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 4], [5, 5]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 4], [5, 6]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 4], [5, 7]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 4], [5, 8]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 4], [5, 9]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 4], [5, 10]]  is =  0.8095238095238095
# Accuracy after transformation  [[0, 4], [6, 0]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 4], [6, 1]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 4], [6, 2]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 4], [6, 3]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 4], [6, 4]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 4], [6, 5]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 4], [6, 6]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 4], [6, 7]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 4], [6, 8]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 4], [6, 9]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 4], [6, 10]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 4], [7, 0]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 4], [7, 1]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 4], [7, 2]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 4], [7, 3]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 4], [7, 4]]  is =  0.6666666666666666
# Accuracy after transformation  [[0, 4], [7, 5]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 4], [7, 6]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 4], [7, 7]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 4], [7, 8]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 4], [7, 9]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 4], [7, 10]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 4], [8, 0]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 4], [8, 1]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 4], [8, 2]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 4], [8, 3]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 4], [8, 4]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 4], [8, 5]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 4], [8, 6]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 4], [8, 7]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 4], [8, 8]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 4], [8, 9]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 4], [8, 10]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 4], [9, 0]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 4], [9, 1]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 4], [9, 2]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 4], [9, 3]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 4], [9, 4]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 4], [9, 5]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 4], [9, 6]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 4], [9, 7]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 4], [9, 8]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 4], [9, 9]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 4], [9, 10]]  is =  0.6666666666666666
# Accuracy after transformation  [[0, 4], [10, 0]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 4], [10, 1]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 4], [10, 2]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 4], [10, 3]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 4], [10, 4]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 4], [10, 5]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 4], [10, 6]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 4], [10, 7]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 4], [10, 8]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 4], [10, 9]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 4], [10, 10]]  is =  0.6904761904761905
# Accuracy after transformation  [[0, 5], [0, 0]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 5], [0, 1]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 5], [0, 2]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 5], [0, 3]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 5], [0, 4]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 5], [0, 5]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 5], [0, 6]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 5], [0, 7]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 5], [0, 8]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 5], [0, 9]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 5], [0, 10]]  is =  0.5952380952380952
# Accuracy after transformation  [[0, 5], [1, 0]]  is =  0.7857142857142857
# Accuracy after transformation  [[0, 5], [1, 1]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 5], [1, 2]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 5], [1, 3]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 5], [1, 4]]  is =  0.7142857142857143
# Accuracy after transformation  [[0, 5], [1, 5]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 5], [1, 6]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 5], [1, 7]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 5], [1, 8]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 5], [1, 9]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 5], [1, 10]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 5], [2, 0]]  is =  0.8095238095238095
# Accuracy after transformation  [[0, 5], [2, 1]]  is =  0.8095238095238095
# Accuracy after transformation  [[0, 5], [2, 2]]  is =  0.7857142857142857
# Accuracy after transformation  [[0, 5], [2, 3]]  is =  0.7857142857142857
# Accuracy after transformation  [[0, 5], [2, 4]]  is =  0.7857142857142857
# Accuracy after transformation  [[0, 5], [2, 5]]  is =  0.7857142857142857
# Accuracy after transformation  [[0, 5], [2, 6]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 5], [2, 7]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 5], [2, 8]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 5], [2, 9]]  is =  0.7380952380952381
# Accuracy after transformation  [[0, 5], [2, 10]]  is =  0.7857142857142857
# Accuracy after transformation  [[0, 5], [3, 0]]  is =  0.7857142857142857
# Accuracy after transformation  [[0, 5], [3, 1]]  is =  0.7857142857142857
# Accuracy after transformation  [[0, 5], [3, 2]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 5], [3, 3]]  is =  0.7619047619047619
# Accuracy after transformation  [[0, 5], [3, 4]]  is =  0.8095238095238095
# ...
# Accuracy after transformation  [[10, 9], [3, 0]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 9], [3, 1]]  is =  0.5952380952380952
# Accuracy after transformation  [[10, 9], [3, 2]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 9], [3, 3]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 9], [3, 4]]  is =  0.5714285714285714
# Accuracy after transformation  [[10, 9], [3, 5]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 9], [3, 6]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 9], [3, 7]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 9], [3, 8]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 9], [3, 9]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 9], [3, 10]]  is =  0.7380952380952381
# Accuracy after transformation  [[10, 9], [4, 0]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 9], [4, 1]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 9], [4, 2]]  is =  0.5952380952380952
# Accuracy after transformation  [[10, 9], [4, 3]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 9], [4, 4]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 9], [4, 5]]  is =  0.5476190476190477
# Accuracy after transformation  [[10, 9], [4, 6]]  is =  0.6428571428571429
# Accuracy after transformation  [[10, 9], [4, 7]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 9], [4, 8]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 9], [4, 9]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 9], [4, 10]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 9], [5, 0]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 9], [5, 1]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 9], [5, 2]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 9], [5, 3]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 9], [5, 4]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 9], [5, 5]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 9], [5, 6]]  is =  0.5714285714285714
# Accuracy after transformation  [[10, 9], [5, 7]]  is =  0.6428571428571429
# Accuracy after transformation  [[10, 9], [5, 8]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 9], [5, 9]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 9], [5, 10]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 9], [6, 0]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 9], [6, 1]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 9], [6, 2]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 9], [6, 3]]  is =  0.6428571428571429
# Accuracy after transformation  [[10, 9], [6, 4]]  is =  0.5952380952380952
# Accuracy after transformation  [[10, 9], [6, 5]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 9], [6, 6]]  is =  0.5714285714285714
# Accuracy after transformation  [[10, 9], [6, 7]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 9], [6, 8]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 9], [6, 9]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 9], [6, 10]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 9], [7, 0]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 9], [7, 1]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 9], [7, 2]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 9], [7, 3]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 9], [7, 4]]  is =  0.5952380952380952
# Accuracy after transformation  [[10, 9], [7, 5]]  is =  0.5952380952380952
# Accuracy after transformation  [[10, 9], [7, 6]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 9], [7, 7]]  is =  0.5952380952380952
# Accuracy after transformation  [[10, 9], [7, 8]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 9], [7, 9]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 9], [7, 10]]  is =  0.6428571428571429
# Accuracy after transformation  [[10, 9], [8, 0]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 9], [8, 1]]  is =  0.7380952380952381
# Accuracy after transformation  [[10, 9], [8, 2]]  is =  0.7380952380952381
# Accuracy after transformation  [[10, 9], [8, 3]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 9], [8, 4]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 9], [8, 5]]  is =  0.5714285714285714
# Accuracy after transformation  [[10, 9], [8, 6]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 9], [8, 7]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 9], [8, 8]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 9], [8, 9]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 9], [8, 10]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 9], [9, 0]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 9], [9, 1]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 9], [9, 2]]  is =  0.7380952380952381
# Accuracy after transformation  [[10, 9], [9, 3]]  is =  0.7380952380952381
# Accuracy after transformation  [[10, 9], [9, 4]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 9], [9, 5]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 9], [9, 6]]  is =  0.5714285714285714
# Accuracy after transformation  [[10, 9], [9, 7]]  is =  0.6428571428571429
# Accuracy after transformation  [[10, 9], [9, 8]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 9], [9, 9]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 9], [9, 10]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 9], [10, 0]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 9], [10, 1]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 9], [10, 2]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 9], [10, 3]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 9], [10, 4]]  is =  0.7619047619047619
# Accuracy after transformation  [[10, 9], [10, 5]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 9], [10, 6]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 9], [10, 7]]  is =  0.5952380952380952
# Accuracy after transformation  [[10, 9], [10, 8]]  is =  0.6428571428571429
# Accuracy after transformation  [[10, 9], [10, 9]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 9], [10, 10]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 10], [0, 0]]  is =  0.6428571428571429
# Accuracy after transformation  [[10, 10], [0, 1]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 10], [0, 2]]  is =  0.6428571428571429
# Accuracy after transformation  [[10, 10], [0, 3]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 10], [0, 4]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 10], [0, 5]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 10], [0, 6]]  is =  0.7380952380952381
# Accuracy after transformation  [[10, 10], [0, 7]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 10], [0, 8]]  is =  0.7380952380952381
# Accuracy after transformation  [[10, 10], [0, 9]]  is =  0.7619047619047619
# Accuracy after transformation  [[10, 10], [0, 10]]  is =  0.7619047619047619
# Accuracy after transformation  [[10, 10], [1, 0]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 10], [1, 1]]  is =  0.6428571428571429
# Accuracy after transformation  [[10, 10], [1, 2]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 10], [1, 3]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 10], [1, 4]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 10], [1, 5]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 10], [1, 6]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 10], [1, 7]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 10], [1, 8]]  is =  0.7380952380952381
# Accuracy after transformation  [[10, 10], [1, 9]]  is =  0.7380952380952381
# Accuracy after transformation  [[10, 10], [1, 10]]  is =  0.7619047619047619
# Accuracy after transformation  [[10, 10], [2, 0]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 10], [2, 1]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 10], [2, 2]]  is =  0.6428571428571429
# Accuracy after transformation  [[10, 10], [2, 3]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 10], [2, 4]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 10], [2, 5]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 10], [2, 6]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 10], [2, 7]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 10], [2, 8]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 10], [2, 9]]  is =  0.7380952380952381
# Accuracy after transformation  [[10, 10], [2, 10]]  is =  0.7380952380952381
# Accuracy after transformation  [[10, 10], [3, 0]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 10], [3, 1]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 10], [3, 2]]  is =  0.5952380952380952
# Accuracy after transformation  [[10, 10], [3, 3]]  is =  0.6428571428571429
# Accuracy after transformation  [[10, 10], [3, 4]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 10], [3, 5]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 10], [3, 6]]  is =  0.6428571428571429
# Accuracy after transformation  [[10, 10], [3, 7]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 10], [3, 8]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 10], [3, 9]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 10], [3, 10]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 10], [4, 0]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 10], [4, 1]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 10], [4, 2]]  is =  0.6428571428571429
# Accuracy after transformation  [[10, 10], [4, 3]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 10], [4, 4]]  is =  0.6428571428571429
# Accuracy after transformation  [[10, 10], [4, 5]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 10], [4, 6]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 10], [4, 7]]  is =  0.6428571428571429
# Accuracy after transformation  [[10, 10], [4, 8]]  is =  0.6428571428571429
# Accuracy after transformation  [[10, 10], [4, 9]]  is =  0.6428571428571429
# Accuracy after transformation  [[10, 10], [4, 10]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 10], [5, 0]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 10], [5, 1]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 10], [5, 2]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 10], [5, 3]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 10], [5, 4]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 10], [5, 5]]  is =  0.6428571428571429
# Accuracy after transformation  [[10, 10], [5, 6]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 10], [5, 7]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 10], [5, 8]]  is =  0.6428571428571429
# Accuracy after transformation  [[10, 10], [5, 9]]  is =  0.6428571428571429
# Accuracy after transformation  [[10, 10], [5, 10]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 10], [6, 0]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 10], [6, 1]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 10], [6, 2]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 10], [6, 3]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 10], [6, 4]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 10], [6, 5]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 10], [6, 6]]  is =  0.6428571428571429
# Accuracy after transformation  [[10, 10], [6, 7]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 10], [6, 8]]  is =  0.5952380952380952
# Accuracy after transformation  [[10, 10], [6, 9]]  is =  0.6428571428571429
# Accuracy after transformation  [[10, 10], [6, 10]]  is =  0.6428571428571429
# Accuracy after transformation  [[10, 10], [7, 0]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 10], [7, 1]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 10], [7, 2]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 10], [7, 3]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 10], [7, 4]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 10], [7, 5]]  is =  0.5952380952380952
# Accuracy after transformation  [[10, 10], [7, 6]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 10], [7, 7]]  is =  0.6428571428571429
# Accuracy after transformation  [[10, 10], [7, 8]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 10], [7, 9]]  is =  0.5952380952380952
# Accuracy after transformation  [[10, 10], [7, 10]]  is =  0.6428571428571429
# Accuracy after transformation  [[10, 10], [8, 0]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 10], [8, 1]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 10], [8, 2]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 10], [8, 3]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 10], [8, 4]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 10], [8, 5]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 10], [8, 6]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 10], [8, 7]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 10], [8, 8]]  is =  0.6428571428571429
# Accuracy after transformation  [[10, 10], [8, 9]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 10], [8, 10]]  is =  0.5952380952380952
# Accuracy after transformation  [[10, 10], [9, 0]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 10], [9, 1]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 10], [9, 2]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 10], [9, 3]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 10], [9, 4]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 10], [9, 5]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 10], [9, 6]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 10], [9, 7]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 10], [9, 8]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 10], [9, 9]]  is =  0.6428571428571429
# Accuracy after transformation  [[10, 10], [9, 10]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 10], [10, 0]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 10], [10, 1]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 10], [10, 2]]  is =  0.7380952380952381
# Accuracy after transformation  [[10, 10], [10, 3]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 10], [10, 4]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 10], [10, 5]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 10], [10, 6]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 10], [10, 7]]  is =  0.5952380952380952
# Accuracy after transformation  [[10, 10], [10, 8]]  is =  0.6428571428571429
# Accuracy after transformation  [[10, 10], [10, 9]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 10], [10, 10]]  is =  0.6428571428571429
# Max Accuarcy obtained at transformation :  [[0, 3], [2, 3]]  i.e Accuracy :  0.8333333333333334

# %% [markdown]
# 2. A. Although it is possible to technically apply the same matrix transform to all features, whether we should or how well it will work will depend on our use case and the goals that we have for our model.

# %% [markdown]
# # Data normalization
#
# Sometimes the features of our data have vastly different scales. This will cause the learning algorithm to give more importance to certain features, reducing its performance. Data normalization is a method in which we transform the features so that they have similar scales.
#
# Three commonly used feature scaling techniques are rescaling, mean normalization and z-score normalization. Here, we will talk about the simplest one: rescaling.
#
# $$\begin{equation}
# x' = \frac {x -min(x)} { max(x) - min(x)}
# \end{equation}$$
#
#
#
# For more information, see [this page](https://towardsdatascience.com/data-normalization-in-machine-learning-395fdec69d02).

# %%
def rescale(data):
  return (data - data.min())/(data.max() - data.min())

# %% [markdown]
# We have to apply the rescaling to each feature individually. Also remember to apply the same transform we are using on the train set to the test set.

# %%
train_feats_rescaled_x = rescale(train_feats[:,0])
train_feats_rescaled_y = rescale(train_feats[:,1])
train_feats_rescaled = np.stack((train_feats_rescaled_x, train_feats_rescaled_y),1)

test_feats_rescaled_x = rescale(test_feats[:,0])
test_feats_rescaled_y = rescale(test_feats[:,1])
test_feats_rescaled = np.stack((test_feats_rescaled_x, test_feats_rescaled_y),1)

# %% [markdown]
# Let us plot the rescaled features:

# %%
fig, ax = plotData(train_feats_rescaled, train_y)

# %% [markdown]
# This type of rescaling makes all the features between 0 and 1.
#
# Let us calculate the accuracy obtained by this transform:

# %%
test_pred = NN(train_feats_rescaled, train_y, test_feats_rescaled)
acc = Accuracy(test_y, test_pred)
print('Accuracy after transform = ', acc)
# Out:
# Accuracy after transform =  0.8095238095238095

# %% [markdown]
# All 2D linear transformations can be repreented by a transformation matrix. So what is the matrix associated with the rescaling function? Actually, we cannot represent rescaling with a matrix multiplication, because it is not a linear transform. Rescaling involves shifting the origin of the data, which is not allowed under linear transformations.
#
# We can represent rescaling as a matrix multiplication followed by a vector addition. Let our first feature vector be called X and second feature vector be called Y. Suppose we want to rescale a data point [a,b]
#
# $$ \begin{equation}
#  \left\{  \begin{aligned}a' \\ b' \end{aligned} \right\} =
#  \left\{  \begin{aligned} \frac{a - min(X)}{max(X) - min(X)} \\ \frac{b - min(Y)}{max(Y) - min(Y)} \end{aligned} \right\} =
#  \left\{  \begin{aligned}&\frac{1}{max(X)-min(X)} &0\\ &0 &\frac{1}{max(Y)-min(Y)} \end{aligned}
#  \right\}\left\{  \begin{aligned}a \\ b \end{aligned} \right\} +
#  \left\{  \begin{aligned} \frac{ -min(X)}{max(X) - min(X)} \\ \frac{-min(Y)}{max(Y) - min(Y)} \end{aligned} \right\}
# \end{equation}$$
#
# You can verify this yourself if you wish, though it is not necessary.
